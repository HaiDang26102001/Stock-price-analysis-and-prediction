# %% [markdown]
# # Để xây dựng mô hình dự báo biến động giá cổ phiếu, em sẽ sử dụng phương pháp LSTM (mạng neuron dài và ngắn)

# %%
import pandas as pd # Đọc và xử lý dữ liệu
import numpy as np # Xử lý dữ liệu
from datetime import datetime as datetime # Chỉnh dữ liệu thời gian
import matplotlib.pyplot as plt # Vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler # Chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint # Lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model # Tải mô hình

# Các lớp để xây dựng mô hình
from keras.models import Sequential # Đầu vào
from keras.layers import LSTM # Học phụ thuộc
from keras.layers import Dropout # Tránh học tủ
from keras.layers import Dense # Đầu ra




# Kiểm định độ chính xác của mô hình
from sklearn.metrics import r2_score # Đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error # Đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error # Đo phần trăm sai số tuyệt đối trung bình

# %% [markdown]
# # Đọc, xử lý và biến đổi dữ liệu

# %%
df = pd.read_csv('VIC.csv')
df.head()
# Out:
#   Ticker        Date/Time  Open  High   Low  Close  Volume  Open Interest
# 0    VIC  10/17/2018 9:39  98.5  98.5  98.5   98.5     390              0
# 1    VIC  10/17/2018 9:40  98.5  98.5  98.5   98.5     760              0
# 2    VIC  10/17/2018 9:41  98.6  98.6  98.6   98.6    2060              0
# 3    VIC  10/17/2018 9:42  98.6  98.6  98.6   98.6    5540              0
# 4    VIC  10/17/2018 9:43  98.6  98.7  98.6   98.7     760              0

# %%
# Thông tin bộ dữ liệu
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101266 entries, 0 to 101265
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Ticker         101266 non-null  object
#  1   Date/Time      101266 non-null  object
#  2   Open           101266 non-null  float64
#  3   High           101266 non-null  float64
#  4   Low            101266 non-null  float64
#  5   Close          101266 non-null  float64
#  6   Volume         101266 non-null  int64
#  7   Open Interest  101266 non-null  int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# => Không có dữ liệu khuyết thiếu

# %%
# Mô tả bộ dữ liệu
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  101266.000000  101266.000000  101266.000000  101266.000000
# mean      105.376460     105.418519     105.334147     105.378791
# std        11.543158      11.535584      11.552338      11.545054
# min        68.000000      68.000000      68.000000      68.000000
# 25%        95.400000      95.400000      95.300000      95.400000
# 50%       105.300000     105.300000     105.200000     105.300000
# 75%       115.800000     115.900000     115.800000     115.800000
# max       126.100000     126.500000     126.100000     126.500000
#
#              Volume  Open Interest
# count  1.012660e+05       101266.0
# mean   3.182640e+03            0.0
# std    1.469814e+04            0.0
# min    1.000000e+01            0.0
# 25%    2.300000e+02            0.0
# 50%    1.020000e+03            0.0
# 75%    3.000000e+03            0.0
# max    1.468390e+06            0.0

# %%
df['Date/Time'] = pd.to_datetime(df["Date/Time"]) # chỉnh kiểu dữ liệu của cột Date/Time
df.head()
# Out:
#   Ticker           Date/Time  Open  High   Low  Close  Volume  Open Interest
# 0    VIC 2018-10-17 09:39:00  98.5  98.5  98.5   98.5     390              0
# 1    VIC 2018-10-17 09:40:00  98.5  98.5  98.5   98.5     760              0
# 2    VIC 2018-10-17 09:41:00  98.6  98.6  98.6   98.6    2060              0
# 3    VIC 2018-10-17 09:42:00  98.6  98.6  98.6   98.6    5540              0
# 4    VIC 2018-10-17 09:43:00  98.6  98.7  98.6   98.7     760              0

# %%
# Tạo list ngày tháng năm
Date = []
for i in df['Date/Time']:
    if datetime.strftime(i,"%Y-%m-%d") not in Date:
        Date.append(datetime.strftime(i,"%Y-%m-%d"))
print(Date)
# Out:
# ['2018-10-17', '2018-10-18', '2018-10-19', '2018-10-22', '2018-10-23', '2018-10-24', '2018-10-25', '2018-10-26', '2018-10-29', '2018-10-30', '2018-10-31', '2018-11-01', '2018-11-02', '2018-11-05', '2018-11-06', '2018-11-07', '2018-11-08', '2018-11-09', '2018-11-12', '2018-11-13', '2018-11-14', '2018-11-15', '2018-11-16', '2018-11-19', '2018-11-20', '2018-11-21', '2018-11-22', '2018-11-23', '2018-11-26', '2018-11-27', '2018-11-28', '2018-11-29', '2018-11-30', '2018-12-03', '2018-12-04', '2018-12-05', '2018-12-06', '2018-12-07', '2018-12-10', '2018-12-11', '2018-12-12', '2018-12-13', '2018-12-14', '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20', '2018-12-21', '2018-12-24', '2018-12-25', '2018-12-26', '2018-12-27', '2018-12-28', '2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-14', '2019-01-15', '2019-01-16', '2019-01-17', '2019-01-18', '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-28', '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01', '2019-02-11', '2019-02-12', '2019-02-13', '2019-02-14', '2019-02-15', '2019-02-18', '2019-02-19', '2019-02-20', '2019-02-21', '2019-02-22', '2019-02-25', '2019-02-26', '2019-02-27', '2019-02-28', '2019-03-01', '2019-03-04', '2019-03-05', '2019-03-06', '2019-03-07', '2019-03-08', '2019-03-11', '2019-03-12', '2019-03-13', '2019-03-14', '2019-03-15', '2019-03-18', '2019-03-19', '2019-03-20', '2019-03-21', '2019-03-22', '2019-03-25', '2019-03-26', '2019-03-27', '2019-03-28', '2019-03-29', '2019-04-01', '2019-04-02', '2019-04-03', '2019-04-04', '2019-04-05', '2019-04-08', '2019-04-09', '2019-04-10', '2019-04-11', '2019-04-12', '2019-04-16', '2019-04-17', '2019-04-18', '2019-04-19', '2019-04-22', '2019-04-23', '2019-04-24', '2019-04-25', '2019-04-26', '2019-05-02', '2019-05-03', '2019-05-06', '2019-05-07', '2019-05-08', '2019-05-09', '2019-05-10', '2019-05-13', '2019-05-14', '2019-05-15', '2019-05-16', '2019-05-17', '2019-05-20', '2019-05-21', '2019-05-22', '2019-05-23', '2019-05-24', '2019-05-27', '2019-05-28', '2019-05-29', '2019-05-30', '2019-05-31', '2019-06-03', '2019-06-04', '2019-06-05', '2019-06-06', '2019-06-07', '2019-06-10', '2019-06-11', '2019-06-12', '2019-06-13', '2019-06-14', '2019-06-17', '2019-06-18', '2019-06-19', '2019-06-20', '2019-06-21', '2019-06-24', '2019-06-25', '2019-06-26', '2019-06-27', '2019-06-28', '2019-07-01', '2019-07-02', '2019-07-03', '2019-07-04', '2019-07-05', '2019-07-08', '2019-07-09', '2019-07-10', '2019-07-11', '2019-07-12', '2019-07-15', '2019-07-16', '2019-07-17', '2019-07-18', '2019-07-19', '2019-07-22', '2019-07-23', '2019-07-24', '2019-07-25', '2019-07-26', '2019-07-29', '2019-07-30', '2019-07-31', '2019-08-01', '2019-08-02', '2019-08-05', '2019-08-06', '2019-08-07', '2019-08-08', '2019-08-09', '2019-08-12', '2019-08-13', '2019-08-14', '2019-08-15', '2019-08-16', '2019-08-19', '2019-08-20', '2019-08-21', '2019-08-22', '2019-08-23', '2019-08-26', '2019-08-27', '2019-08-28', '2019-08-29', '2019-08-30', '2019-09-03', '2019-09-04', '2019-09-05', '2019-09-06', '2019-09-09', '2019-09-10', '2019-09-11', '2019-09-12', '2019-09-13', '2019-09-16', '2019-09-17', '2019-09-18', '2019-09-19', '2019-09-20', '2019-09-23', '2019-09-24', '2019-09-25', '2019-09-26', '2019-09-27', '2019-09-30', '2019-10-01', '2019-10-02', '2019-10-03', '2019-10-04', '2019-10-07', '2019-10-08', '2019-10-09', '2019-10-10', '2019-10-11', '2019-10-14', '2019-10-15', '2019-10-16', '2019-10-17', '2019-10-18', '2019-10-21', '2019-10-22', '2019-10-23', '2019-10-24', '2019-10-25', '2019-10-28', '2019-10-29', '2019-10-30', '2019-10-31', '2019-11-01', '2019-11-04', '2019-11-05', '2019-11-06', '2019-11-07', '2019-11-08', '2019-11-11', '2019-11-12', '2019-11-13', '2019-11-14', '2019-11-15', '2019-11-18', '2019-11-19', '2019-11-20', '2019-11-21', '2019-11-22', '2019-11-25', '2019-11-26', '2019-11-27', '2019-11-28', '2019-11-29', '2019-12-02', '2019-12-03', '2019-12-04', '2019-12-05', '2019-12- ...

# %%
# Tạo list giá mở cửa, đóng cửa, cao nhất, thấp nhất
Open = []
High = []
Low = []
Close = []
for date in Date:
    subset = df[df['Date/Time'].dt.date == datetime.strptime(date, '%Y-%m-%d').date()]
    Open.append(subset.iloc[0]['Open'])
    High.append(subset['High'].max())
    Low.append(subset['Low'].min())
    Close.append(subset.iloc[-1]['Close'])

# %%
# Tạo 1 dataframe chứa dữ liệu giao dịch theo từng ngày
price_data_series = {
    'Tiker':df['Ticker'][:len(Date)],
    'Date': Date,
    'Open': Open,
    'High':High,
    'Low':Low,
    'Close':Close
}
VIC = pd.DataFrame(price_data_series)
VIC
# Out:
#     Tiker        Date   Open   High    Low  Close
# 0     VIC  2018-10-17   98.5   99.6   98.3   99.0
# 1     VIC  2018-10-18   98.5   99.2   98.0   99.1
# 2     VIC  2018-10-19   96.5   99.1   96.5   99.1
# 3     VIC  2018-10-22   98.1   99.6   97.1   99.1
# 4     VIC  2018-10-23   98.1   99.0   96.5   99.0
# ..    ...         ...    ...    ...    ...    ...
# 543   VIC  2020-12-16  106.8  107.1  105.9  107.0
# 544   VIC  2020-12-17  106.3  106.9  104.7  104.7
# 545   VIC  2020-12-18  104.7  106.1  104.5  104.7
# 546   VIC  2020-12-21  105.5  106.4  104.9  106.4
# 547   VIC  2020-12-22  106.0  107.0  105.3  105.7
#
# [548 rows x 6 columns]

# %% [markdown]
# Mô hình của sẽ sử dụng dữ liệu của giá đóng cửa trong quá khứ làm cơ sở để dự báo giá trong tương lai
#
# => Vì vậy sẽ lấy ra dữ liệu ngày và giá đóng cửa trong Dataframe VIC

# %%
df1 = pd.DataFrame(VIC, columns=['Date','Close'])
df1['Date'] = pd.to_datetime(df1['Date'])
df1.index = df1['Date']
df1.drop('Date',axis=1,inplace=True)
df1
# Out:
#             Close
# Date
# 2018-10-17   99.0
# 2018-10-18   99.1
# 2018-10-19   99.1
# 2018-10-22   99.1
# 2018-10-23   99.0
# ...           ...
# 2020-12-16  107.0
# 2020-12-17  104.7
# 2020-12-18  104.7
# 2020-12-21  106.4
# 2020-12-22  105.7
#
# [548 rows x 1 columns]

# %%
# Vẽ biểu đồ giá đóng cửa 
plt.figure(figsize=(10,5))
plt.plot(df1['Close'],label='Giá thực tế',color='red')
plt.title('Biểu đồ giá đóng cửa')
plt.xlabel('Ngày giao dịch')
plt.ylabel('Giá đóng cửa ( nghìn VND)')
plt.show()

# %% [markdown]
# Nhìn vào biểu đồ giá đóng của của mã Chứng khoán VIC từ tháng 10/2018 tới cuối năm 2020 ta thấy:
# + Vào khoảng thời gian từ cuối năm 2018 tới cuối năm 2019 là đỉnh cao của VIC, đỉnh sau cao hơn đỉnh trước, đáy sau cao hơn đáy trước, và đạt đỉnh vào quý 3 năm 2019 với mức giá 126.1 nghìn VND
# + Tới đầu năm 2020, đại dịch Covid 19 ập đến, với bản chất là 1 cổ phiếu trụ của thị trường, thời gian đầu VIC vẫn rất mạnh mẽ giữ được giá ở trong khoảng hơn 110 nghìn VND, nhưng với tình hình ngày càng tệ VIC cũng không tránh khỏi cú sập do Covid 19 mang lại, nhà đầu tư hoảng loạn đặt bán, khiến cho giá của VIC rơi xuống đáy thấp nhất trong giai đoạn này chỉ còn 71.5 nghìn VND vào tháng 3/2020
# + Nhưng cũng ngay sau đó VIC cũng đã hồi phục cùng với các cổ phiếu trụ khác kéo cả thị trường vực dậy, tới cuối năm 2020, VIC giao dịch xung quanh mức giá 100 nghìn VND

# %%
# Chia tập dữ liệu ra thành 2 phần train và test để đánh giá hiệu suất của mô hình học máy trên tập dữ liệu

data = df1.values
train_data = data[:400]
test_data = data[400:]

# %%
# Chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))
# MinmaxScaler sẽ điều chỉnh dữ liệu: giá trị nhỏ nhất sẽ là 0, giá trị lớn nhất sẽ là 1, các giá trị khác sẽ theo tỷ lệ giữa 0 và 1
sc_train = sc.fit_transform(data)

# %%
# Ý tưởng của mô hình là sử dụng giá của 40 ngày liên tục để dự đoán giá của ngày tiếp theo
x_train, y_train = [],[]
for i in range(40,len(train_data)):
    x_train.append(sc_train[i-40:i,0])
    y_train.append(sc_train[i,0])

# %% [markdown]
# => x_train sẽ bao gồm các mảng, mỗi bảng sẽ bao gồm 40 giá đóng cửa liên tục
#     y_train sẽ bao gồm 1 danh sách giá đóng cửa của ngày hôm sau tương ứng với mỗi mảng của x_train

# %%
# Sắp xếp dữ liệu thành 1 mảng
x_train = np.array(x_train)
y_train = np.array(y_train)

# xếp lại dữ liệu thành mảng 1 chiều
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

# %%
import os
# Bao gồm 5 lớp mô hình
from tensorflow.keras.callbacks import ModelCheckpoint
model = Sequential() # Lớp đầu vào input, tạo lớp mạng cho dữ liệu đầu vào
model.add(LSTM(units=128, input_shape=(x_train.shape[1],1), return_sequences=True)) # Mô tả thông tin của đầu vào 
model.add(LSTM(units=64))
model.add(Dropout(0.5)) # Lớp dropout sẽ random đặt 1 số giá trị trong lúc training về bằng 0 để buộc cho máy học phải học lại, tránh tình trạng overfit ( học tủ )
model.add(Dense(units=1)) # Lớp output với đầu ra 1 chiều
model.compile(loss="mean_absolute_error", optimizer='adam') # hàm sai số loss sẽ đo sai số tuyệt đối trung bình
save_model = "C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán/model6.hdf5" # sau khi training sẽ lưu vào file dạng HDF5

best_model = ModelCheckpoint( monitor='loss', verbose=1, save_best_only=True, mode="min",filepath=save_model) # Training tìm ra mô hình huấn luyện tốt nhất và chỉ lưu duy nhất 1 kết quả
model.fit(x_train, y_train, epochs=100, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.31584, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 3s - loss: 0.3158 - 3s/epoch - 359ms/step
# Epoch 2/100
#
# Epoch 2: loss improved from 0.31584 to 0.14906, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.1491 - 347ms/epoch - 43ms/step
# Epoch 3/100
#
# Epoch 3: loss improved from 0.14906 to 0.12803, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.1280 - 344ms/epoch - 43ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.12803 to 0.11821, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.1182 - 370ms/epoch - 46ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.11821 to 0.11202, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.1120 - 351ms/epoch - 44ms/step
# Epoch 6/100
#
# Epoch 6: loss improved from 0.11202 to 0.09769, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0977 - 388ms/epoch - 48ms/step
# Epoch 7/100
#
# Epoch 7: loss did not improve from 0.09769
# 8/8 - 0s - loss: 0.1025 - 328ms/epoch - 41ms/step
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.09769
# 8/8 - 0s - loss: 0.1002 - 323ms/epoch - 40ms/step
# Epoch 9/100
#
# Epoch 9: loss did not improve from 0.09769
# 8/8 - 0s - loss: 0.0981 - 325ms/epoch - 41ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.09769 to 0.09508, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0951 - 337ms/epoch - 42ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.09508 to 0.09286, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0929 - 343ms/epoch - 43ms/step
# Epoch 12/100
#
# Epoch 12: loss did not improve from 0.09286
# 8/8 - 0s - loss: 0.0954 - 330ms/epoch - 41ms/step
# Epoch 13/100
#
# Epoch 13: loss improved from 0.09286 to 0.08817, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0882 - 347ms/epoch - 43ms/step
# Epoch 14/100
#
# Epoch 14: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0904 - 365ms/epoch - 46ms/step
# Epoch 15/100
#
# Epoch 15: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.1025 - 333ms/epoch - 42ms/step
# Epoch 16/100
#
# Epoch 16: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0983 - 341ms/epoch - 43ms/step
# Epoch 17/100
#
# Epoch 17: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0944 - 362ms/epoch - 45ms/step
# Epoch 18/100
#
# Epoch 18: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0965 - 331ms/epoch - 41ms/step
# Epoch 19/100
#
# Epoch 19: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0954 - 337ms/epoch - 42ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0963 - 333ms/epoch - 42ms/step
# Epoch 21/100
#
# Epoch 21: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0985 - 351ms/epoch - 44ms/step
# Epoch 22/100
#
# Epoch 22: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.1036 - 348ms/epoch - 44ms/step
# Epoch 23/100
#
# Epoch 23: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0973 - 336ms/epoch - 42ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0933 - 345ms/epoch - 43ms/step
# Epoch 25/100
#
# Epoch 25: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.1010 - 340ms/epoch - 43ms/step
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.1025 - 368ms/epoch - 46ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0925 - 338ms/epoch - 42ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0887 - 336ms/epoch - 42ms/step
# Epoch 29/100
#
# Epoch 29: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0902 - 337ms/epoch - 42ms/step
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0890 - 385ms/epoch - 48ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.08817
# 8/8 - 0s - loss: 0.0895 - 354ms/epoch - 44ms/step
# Epoch 32/100
#
# Epoch 32: loss improved from 0.08817 to 0.08730, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0873 - 369ms/epoch - 46ms/step
# Epoch 33/100
#
# Epoch 33: loss improved from 0.08730 to 0.08170, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0817 - 371ms/epoch - 46ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.08170
# 8/8 - 0s - loss: 0.0851 - 364ms/epoch - 46ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.08170
# 8/8 - 0s - loss: 0.0837 - 352ms/epoch - 44ms/step
# Epoch 36/100
#
# Epoch 36: loss improved from 0.08170 to 0.08119, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0812 - 365ms/epoch - 46ms/step
# Epoch 37/100
#
# Epoch 37: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.0858 - 354ms/epoch - 44ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.0888 - 364ms/epoch - 46ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.1056 - 355ms/epoch - 44ms/step
# Epoch 40/100
#
# Epoch 40: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.0911 - 353ms/epoch - 44ms/step
# Epoch 41/100
#
# Epoch 41: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.0863 - 353ms/epoch - 44ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.0868 - 360ms/epoch - 45ms/step
# Epoch 43/100
#
# Epoch 43: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.0837 - 368ms/epoch - 46ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.0868 - 369ms/epoch - 46ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.0879 - 361ms/epoch - 45ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.08119
# 8/8 - 0s - loss: 0.0861 - 366ms/epoch - 46ms/step
# Epoch 47/100
#
# Epoch 47: loss improved from 0.08119 to 0.08092, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0809 - 398ms/epoch - 50ms/step
# Epoch 48/100
#
# Epoch 48: loss did not improve from 0.08092
# 8/8 - 0s - loss: 0.0821 - 374ms/epoch - 47ms/step
# Epoch 49/100
#
# Epoch 49: loss improved from 0.08092 to 0.07833, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0783 - 397ms/epoch - 50ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.07833
# 8/8 - 0s - loss: 0.0796 - 374ms/epoch - 47ms/step
# Epoch 51/100
#
# Epoch 51: loss did not improve from 0.07833
# 8/8 - 0s - loss: 0.0795 - 369ms/epoch - 46ms/step
# Epoch 52/100
#
# Epoch 52: loss did not improve from 0.07833
# 8/8 - 0s - loss: 0.0805 - 364ms/epoch - 46ms/step
# Epoch 53/100
#
# Epoch 53: loss improved from 0.07833 to 0.07493, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0749 - 391ms/epoch - 49ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.07493
# 8/8 - 0s - loss: 0.0784 - 407ms/epoch - 51ms/step
# Epoch 55/100
#
# Epoch 55: loss did not improve from 0.07493
# 8/8 - 0s - loss: 0.0842 - 382ms/epoch - 48ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.07493
# 8/8 - 0s - loss: 0.0759 - 363ms/epoch - 45ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.07493
# 8/8 - 0s - loss: 0.0779 - 366ms/epoch - 46ms/step
# Epoch 58/100
#
# Epoch 58: loss improved from 0.07493 to 0.07367, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0737 - 393ms/epoch - 49ms/step
# Epoch 59/100
#
# Epoch 59: loss did not improve from 0.07367
# 8/8 - 0s - loss: 0.0745 - 370ms/epoch - 46ms/step
# Epoch 60/100
#
# Epoch 60: loss improved from 0.07367 to 0.07212, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0721 - 385ms/epoch - 48ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.07212
# 8/8 - 0s - loss: 0.0757 - 476ms/epoch - 59ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.07212
# 8/8 - 0s - loss: 0.0733 - 482ms/epoch - 60ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.07212
# 8/8 - 0s - loss: 0.0744 - 444ms/epoch - 56ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.07212
# 8/8 - 0s - loss: 0.0738 - 458ms/epoch - 57ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.07212
# 8/8 - 0s - loss: 0.0762 - 474ms/epoch - 59ms/step
# Epoch 66/100
#
# Epoch 66: loss did not improve from 0.07212
# 8/8 - 1s - loss: 0.0738 - 506ms/epoch - 63ms/step
# Epoch 67/100
#
# Epoch 67: loss improved from 0.07212 to 0.07132, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0713 - 456ms/epoch - 57ms/step
# Epoch 68/100
#
# Epoch 68: loss improved from 0.07132 to 0.07038, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0704 - 495ms/epoch - 62ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.07038
# 8/8 - 0s - loss: 0.0735 - 455ms/epoch - 57ms/step
# Epoch 70/100
#
# Epoch 70: loss improved from 0.07038 to 0.06857, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0686 - 464ms/epoch - 58ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0718 - 465ms/epoch - 58ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0763 - 447ms/epoch - 56ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0730 - 444ms/epoch - 56ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0707 - 457ms/epoch - 57ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0706 - 438ms/epoch - 55ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0726 - 434ms/epoch - 54ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0794 - 442ms/epoch - 55ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0745 - 452ms/epoch - 57ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0819 - 453ms/epoch - 57ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0735 - 444ms/epoch - 56ms/step
# Epoch 81/100
#
# Epoch 81: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0746 - 495ms/epoch - 62ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0693 - 456ms/epoch - 57ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.06857
# 8/8 - 0s - loss: 0.0705 - 438ms/epoch - 55ms/step
# Epoch 84/100
#
# Epoch 84: loss improved from 0.06857 to 0.06541, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0654 - 476ms/epoch - 60ms/step
# Epoch 85/100
#
# Epoch 85: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0682 - 464ms/epoch - 58ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0666 - 443ms/epoch - 55ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0672 - 446ms/epoch - 56ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0683 - 442ms/epoch - 55ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0711 - 436ms/epoch - 55ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0658 - 457ms/epoch - 57ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0662 - 442ms/epoch - 55ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0697 - 454ms/epoch - 57ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0695 - 485ms/epoch - 61ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0688 - 469ms/epoch - 59ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.06541
# 8/8 - 0s - loss: 0.0665 - 444ms/epoch - 56ms/step
# Epoch 96/100
#
# Epoch 96: loss improved from 0.06541 to 0.06302, saving model to C:/Users/DD/Desktop/Phân tích và dự báo giá chứng khoán\model6.hdf5
# 8/8 - 0s - loss: 0.0630 - 454ms/epoch - 57ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.06302
# 8/8 - 0s - loss: 0.0635 - 438ms/epoch - 55ms/step
# Epoch 98/100
#
# Epoch 98: loss did not improve from 0.06302
# 8/8 - 0s - loss: 0.0660 - 461ms/epoch - 58ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.06302
# 8/8 - 0s - loss: 0.0645 - 439ms/epoch - 55ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.06302
# 8/8 - 0s - loss: 0.0632 - 459ms/epoch - 57ms/step

# %% [markdown]
# Trong 100 lần training nếu mô hình nào có sai số tuyệt đối trung bình nhỏ hơn mô hình trước thì sẽ được tự động lưu vào file HDF5 và ghi đè lên mô hình đã lưu trước đó ( Vì save_best_only = True)

# %%
# Sau khi tìm được mô hình tốt nhất và lưu trong file 'model6.hdf5', tải lên lại mô hình và áp dụng dự đoán vào tập train
import io
import h5py
with open('model6.hdf5', 'rb') as f:
    file_content = f.read()
    with io.BytesIO(file_content) as file:
        with h5py.File(file, 'r') as hdf:
            final_model = load_model(hdf)

y_train = sc.inverse_transform(y_train) # giá thực
y_train_predict = final_model.predict(x_train)
y_train_predict = sc.inverse_transform(y_train_predict) # Giá dự đoán

# Dùng inverse_tranform để điều chỉnh về định dạnh dữ liệu gốc vì dữ liệu đang được chuẩn hóa ở dạng trong khoảng từ 0 đến 1
# Out:
# 12/12 [==============================] - 1s 9ms/step

# %% [markdown]
# # Sử dụng mô hình

# %%
# Với tập test làm tương tự như tập train
test = df1[len(train_data)-40:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(40,test.shape[0]):
    x_test.append(sc_test[i-40:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))


# dữ liệu test
y_test = data[400:] # Giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) # giá dự đoán
# Out:
# 5/5 [==============================] - 0s 9ms/step

# %% [markdown]
# # Độ chính xác của mô hình

# %%
train_data1 = df1[40:400]
test_data1 = df1[400:]

plt.figure(figsize=(24,8))

plt.plot(df1,label='Giá thực tế',color='red')


train_data1['dự đoán'] = y_train_predict

plt.plot(train_data1['dự đoán'], label='Giá dự đoán train', color='green')


test_data1['Dự đoán'] = y_test_predict
plt.plot(test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')

plt.title("so sánh giá dự đoán với giá thực tế")

plt.xlabel('thời gian')

plt.ylabel('Giá đóng cửa (nghìn VND)')
plt.legend()

plt.show()
# Out:
# C:\Users\DD\AppData\Local\Temp\ipykernel_9428\1296178694.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data1['dự đoán'] = y_train_predict
# C:\Users\DD\AppData\Local\Temp\ipykernel_9428\1296178694.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['Dự đoán'] = y_test_predict

# %% [markdown]
# Để kiểm tra độ chính xác của mô hình, đầu tiên ta lập biểu đồ so sánh ở trên cả 2 tập.
#
# + Với giá thực tế của cổ phiếu được biểu diễn bằng đường màu đỏ
# + Giá dự đoán của tập train được biểu diễn bằng đường màu xanh lá
# + Giá dự đoán của tập test được biển diễn bằng đường màu xanh dương

# %% [markdown]
# Để cụ thể hơn thì sẽ đánh giá bằng r2_score

# %%
#r2
print('Độ phù hợp của tập train: ',r2_score(y_train, y_train_predict))

#mae
print('Sai số tuyệt đối trung bình tập train: ',mean_absolute_error(y_train,y_train_predict))

#mape
print('Phần trăm sai số tuyệt đối trung bình tập train: ',mean_absolute_percentage_error(y_train,y_train_predict))
# Out:
# Độ phù hợp của tập train:  0.9447016704133734
# Sai số tuyệt đối trung bình tập train:  1.4581135304768882
# Phần trăm sai số tuyệt đối trung bình tập train:  0.013922358327744513

# %%
train_data1
# Out:
#             Close     dự đoán
# Date
# 2018-12-12  102.2  101.792694
# 2018-12-13  102.8  101.973633
# 2018-12-14  102.7  102.271530
# 2018-12-17  102.5  102.566750
# 2018-12-18  102.0  102.768784
# ...           ...         ...
# 2020-05-21   98.0   96.337418
# 2020-05-22   96.4   96.624931
# 2020-05-25   97.1   96.792519
# 2020-05-26   96.9   97.006981
# 2020-05-27   96.9   97.173447
#
# [360 rows x 2 columns]

# %%
#r2
print('Độ phù hợp của tập test: ',r2_score(y_test, y_test_predict))

#mae
print('Sai số tuyệt đối trung bình tập test: ',mean_absolute_error(y_test,y_test_predict))

#mape
print('Phần trăm sai số tuyệt đối trung bình tập train: ',mean_absolute_percentage_error(y_test,y_test_predict))
# Out:
# Độ phù hợp của tập test:  0.9100380072882781
# Sai số tuyệt đối trung bình tập test:  1.5451519940350502
# Phần trăm sai số tuyệt đối trung bình tập train:  0.016351328525894823

# %%
test_data1
# Out:
#             Close     Dự đoán
# Date
# 2020-05-28   97.0   97.284317
# 2020-05-29   97.0   97.361717
# 2020-06-01   97.2   97.406113
# 2020-06-02   96.7   97.461693
# 2020-06-03   96.8   97.418724
# ...           ...         ...
# 2020-12-16  107.0  107.087166
# 2020-12-17  104.7  107.380981
# 2020-12-18  104.7  107.015663
# 2020-12-21  106.4  106.354362
# 2020-12-22  105.7  105.991814
#
# [148 rows x 2 columns]

# %% [markdown]
# Với mã ck VIC thì mô hình dự đoán LSTM cũng cho ra một độ phù hợp khá cao, trên 94% với tập train và trên 91% với tập test
# => Có thể thấy là mô hình dự đoán biến động giá chứng khoán có sử dụng thuật bán LSTM cho ra 1 kết quả dự đoán khá cao, có thế giúp ích được cho các nhà đầu tư trong việc đưa ra các quyết định trong thị trường chứng khoán.
#
# => Tuy nhiên trong thị trường này còn rất nhiều yếu tố khác nhau có thể tác động tới xu hướng biến động của giá cổ phiếu cũng như độ sai số của mô hình, vì vậy các nhà đầu tư chỉ nên tham khảo và có những nhận định kĩ lưỡng trước khi đưa ra quyết định đầu tư
